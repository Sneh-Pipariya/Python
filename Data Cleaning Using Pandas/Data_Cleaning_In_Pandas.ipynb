# %%
import pandas as pd

# %%
df = pd.read_excel(r"/Users/snehpipariya/Documents/Data Analyst Bootcamp by Alex Youtuber/Python/Data Cleaning Using Pandas/Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# # Remove Duplicates

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# # Drop Columns

# %%
df = df.drop(columns = "Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# # Strip

# %%
df["Last_Name"] = df["Last_Name"].str.strip("_./")
df
# Out:
# /var/folders/_h/rq5lqj1904l8pjsbsq7tq3gh0000gn/T/ipykernel_8058/3135555974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Last_Name"] = df["Last_Name"].str.strip("_./")
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# 5         1006        Ron     Swanson   3047622467
# 6         1007       Jeff      Winger          NaN
# 7         1008   Sherlock      Holmes   8766783469
# 8         1009    Gandalf         NaN           Na
# ...

# %% [markdown]
# # Cleaning/Standardizing Phone Numbers

# %%
# df["Phone_Number"] = df["Phone_Number"].str.replace('[^a-zA-Z0-9]','',regex=True)

# df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))
# df
# df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + "-" + x[3:6] + "-" + x[6:10])
df["Phone_Number"] = df["Phone_Number"].str.replace('nan--',"")
df["Phone_Number"] = df["Phone_Number"].str.replace('Na--',"")
df
# Out:
# /var/folders/_h/rq5lqj1904l8pjsbsq7tq3gh0000gn/T/ipykernel_8058/3365129280.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].str.replace('nan--',"")
# /var/folders/_h/rq5lqj1904l8pjsbsq7tq3gh0000gn/T/ipykernel_8058/3365129280.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Phone_Number"] = df["Phone_Number"].str.replace('Na--',"")
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# ...

# %% [markdown]
# # Split Columns

# %%
df[["Street Address","State","Zip"]] = df["Address"].str.rsplit(',',n=2, expand=True)
df
# Out:
# /var/folders/_h/rq5lqj1904l8pjsbsq7tq3gh0000gn/T/ipykernel_8058/2941219055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Street Address","State","Zip"]] = df["Address"].str.rsplit(',',n=2, expand=True)
# /var/folders/_h/rq5lqj1904l8pjsbsq7tq3gh0000gn/T/ipykernel_8058/2941219055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Street Address","State","Zip"]] = df["Address"].str.rsplit(',',n=2, expand=True)
# ...

# %% [markdown]
# # Standardizing column values using Replace

# %%
df["Paying Customer"] = df["Paying Customer"].str.replace("Yes","Y")
df["Paying Customer"] = df["Paying Customer"].str.replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("Yes","Y")
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace("No","N")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df = df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df = df.drop(columns = "Address")
df = df.drop(columns = "State & Zip")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123/643/9775               N
# 2         1003     Walter       White    7066950392               N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876|678|3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876|678|3469               N
# 8         1009    Gandalf                       N/a               Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter    7066950392               Y
# 12        1013        Don      Draper  123-543-2345               Y
# ...

# %% [markdown]
# # Filtering down rows of data

# %%
for x in df.index:
    if df.loc[x,"Do_Not_Contact"] == 'Y':
        df.drop(x,inplace=True)

# df = df.dropna(subset=["Phone_Number"], inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 for x in df.index:
#       2     if df.loc[x,"Do_Not_Contact"] == 'Y':
#       3         df.drop(x,inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'index'

# %%
df = df.reset_index(drop = True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1003     Walter       White    7066950392               N
# 2         1005        Jon        Snow  876|678|3469               Y
# 3         1008   Sherlock      Holmes  876|678|3469               N
# 4         1009    Gandalf                       N/a               Y
# 5         1010      Peter      Parker  123-545-5421               Y
# 6         1012      Harry      Potter    7066950392               Y
# 7         1013        Don      Draper  123-543-2345               Y
# 8         1014     Leslie       Knope  876|678|3469               Y
# 9         1015       Toby  Flenderson  304-762-2467               N
# 10        1016        Ron     Weasley  123-545-5421               N
# 11        1017   Michael        Scott  123/643/9775               Y
# 12        1018      Clark        Kent    7066950392               Y
# ...
